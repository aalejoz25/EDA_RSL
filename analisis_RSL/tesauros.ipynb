# %% [markdown]
# # Tesauros y su Uso en la Investigación
#
# Los tesauros son vocabularios controlados y estructurados que ayudan a organizar y estandarizar términos en un campo específico. Son fundamentales para realizar búsquedas sistemáticas de literatura.
#
# ## Tesauros estandarizados:
#
# ### 1. AGROVOC (FAO)
# - **Descripción**: Tesauro multilingüe de la FAO que cubre agricultura, silvicultura, pesca y alimentación
# - **Utilidad**: Excelente para términos relacionados con cultivos y agricultura
# - **Acceso**: [AGROVOC](http://aims.fao.org/vest-registry/vocabularies/agrovoc)
#
# ### 2. CAB Thesaurus
# - **Descripción**: Especializado en ciencias de la vida, incluyendo agricultura y ciencias vegetales
# - **Utilidad**: Muy útil para términos sobre enfermedades de plantas y cultivos
# - **Acceso**: [CAB Thesaurus](https://www.cabi.org/cabthesaurus/)
#
# ### 3. IEEE Thesaurus
# - **Descripción**: Vocabulario controlado para términos técnicos y de ingeniería
# - **Utilidad**: Perfecto para términos de IA y procesamiento de datos
# - **Acceso**: Disponible a través de IEEE Xplore
# - [IEEE Thesaurus](https://ieee-org.widen.net/s/ljqzpfxm5g/ieee-thesaurus)
#
# ### 4. NAL Agricultural Thesaurus
# - **Descripción**: Tesauro de la Biblioteca Nacional de Agricultura de EE.UU.
# - **Utilidad**: Específico para términos agrícolas y de cultivos
# - **Acceso**: [NAL Thesaurus](https://agclass.nal.usda.gov/)

# %% [markdown]
# ### Beneficios de Usar Tesauros en la Búsqueda:
# 1. **Exhaustividad**: Asegura que no se pierdan documentos relevantes
# 2. **Precisión**: Reduce el ruido en los resultados
# 3. **Consistencia**: Mantiene coherencia en la terminología
# 4. **Jerarquía**: Permite expandir o reducir el alcance de la búsqueda

# %% [markdown]
# ## Uso de los tesauros
#
# ### Pasos para una Búsqueda Efectiva:
#
# 1. **Identificar Conceptos Clave o Macro**
#
# 2. **Consultar Tesauros Específicos**
#    - AGROVOC: Para términos agrícolas
#    - CAB Thesaurus: Para enfermedades de plantas
#    - IEEE Thesaurus: Para términos de IA y asociados a ingenieria
#
# 3. **Construir Jerarquías de Términos**
#    - Identificar términos más específicos
#    - Identificar términos relacionados
#    - Identificar términos más amplios
#
# 4. **Combinar Términos**
#    - Usar operadores booleanos (AND, OR)
#    - Incluir variaciones de términos
#    - Considerar sinónimos y términos relacionados

# %% [markdown]
# # Resumen de Tesauros: ScienceDirect
#
# ## Definición y Evolución
# Los tesauros han evolucionado desde su concepción original como "tesoro de palabras" hasta convertirse en herramientas sofisticadas para la organización y recuperación de información. Según las definiciones modernas, un tesauro es:
#
# - Un vocabulario controlado y dinámico
# - Una herramienta que establece relaciones semánticas y sintácticas entre términos
# - Un instrumento para el control terminológico en sistemas de información
#
# ## Características Principales
# 1. **Estructura Formal**
#    - Relaciones jerárquicas entre conceptos
#    - Relaciones semánticas entre términos
#    - Control de vocabulario
#    - Organización sistemática
#
# 2. **Funcionalidades**
#    - Control terminológico
#    - Ayuda en la recuperación de información
#    - Expansión de consultas
#    - Normalización de vocabulario
#
# ## Tipos de Tesauros
# 1. **Por Alcance**
#    - Generales
#    - Especializados
#    - Multidisciplinarios
#    - Monodisciplinarios
#
# 2. **Por Estructura**
#    - Alfabéticos
#    - Sistemáticos (temáticos)
#    - Gráficos
#
# 3. **Por Tamaño**
#    - Macrotesauros
#    - Microtesauros
#
# 4. **Por Idioma**
#    - Monolingües
#    - Bilingües
#    - Plurilingües
#
# ## Control Terminológico
# Los tesauros pueden ser:
# 1. **Controlados**
#    - Un solo término por concepto
#    - Relaciones estandarizadas
#    - Significados delimitados
#
# 2. **De lenguaje libre**
#    - Múltiples términos por concepto
#    - Mayor flexibilidad
#    - Basados en literatura relevante
#
# ## Usos Modernos
# 1. Indexación de documentos
# 2. Búsqueda y recuperación de información
# 3. Apoyo en sistemas de IA y procesamiento de lenguaje natural
# 4. Organización del conocimiento
# 5. Desarrollo de ontologías y taxonomías
#
# Referencia: [https://www.sciencedirect.com/topics/social-sciences/thesauri](https://www.sciencedirect.com/topics/social-sciences/thesauri)

# %% [markdown]
# # Identificacion de Conceptos Macro para la Ecuación de Búsqueda
#
# ## Facetas Principales
#
# ### Faceta 1: TECNOLOGÍA (Herramientas y Métodos)
# ```
# ("artificial intelligence" OR "machine learning" OR "deep learning" OR
#  "neural network*" OR "computer vision" OR "image processing" OR
#  "pattern recognition")
# ```
#
# ### Faceta 2: ENFERMEDADES (Contexto/Problema)
# ```
# ("plant disease*" OR "crop disease*" OR "pathogen*" OR
#  "disease detection" OR "disease assessment" OR "pest*" OR
#  "plant health" OR "crop infection*")
# ```
#
# ### Faceta 3: PREDICCIÓN Y MODELADO (Acción/Propósito)
# ```
# ("predict*" OR "forecast*" OR "model*" OR "estimation" OR
#  "early detection" OR "assessment" OR "monitoring" OR
#  "analysis" OR "evaluation")
# ```
#
# ### Faceta 4: OBJETO DE ESTUDIO (Objetivo Final)
# ```
# ("crop yield" OR "fruit quality" OR "harvest quality" OR
#  "production quality" OR "crop performance")
# ```
#
# ## Justificacion del orden de las facetas
#
# 1. **Tecnología** (¿Con qué herramientas?)
#    - Define las herramientas y métodos disponibles
#    - Base tecnológica para la solución
#
# 2. **Enfermedades** (¿Cuál es el problema?)
#    - Define el contexto del problema
#    - Establece el ámbito de aplicación
#    - Identifica la variable independiente principal
#
# 3. **Predicción** (¿Qué queremos hacer?)
#    - Define la acción sobre el problema
#    - Establece el tipo de análisis
#    - Conecta el problema con el objetivo
#
# 4. **Objeto de Estudio** (¿Qué queremos impactar?)
#    - Define el objetivo final
#    - Establece las variables dependientes
#    - Determina los resultados esperados
#
# ## Ejemplo de Construcción Progresiva Refinada
#
# 1. **Base Tecnológica**:
#    ```
#    ("artificial intelligence" OR "machine learning" OR "computer vision")
#    ```
#
# 2. **+ Contexto del Problema**:
#    ```
#    [Nivel 1] AND ("plant disease*" OR "crop disease*" OR "pathogen*")
#    ```
#
# 3. **+ Propósito de Análisis**:
#    ```
#    [Nivel 2] AND ("predict*" OR "forecast*" OR "model*")
#    ```
#
# 4. **+ Objetivo Final**:
#    ```
#    [Nivel 3] AND ("crop yield" OR "fruit quality")
#    ```
#
# ## ¿Como afecta el orden logico al analisis?
#
# 1. **Flujo Lógico**:
#    - De herramientas → problema → acción → objetivo
#    - Sigue un proceso de pensamiento natural
#    - Facilita la comprensión del alcance
#
# 2. **Claridad en las relaciones**:
#    - Vincula directamente el problema con su solución
#    - Establece clara relación causa-efecto
#    - Mejora la identificación de variables
#
# 3. **Mayor Precisión**:
#    - Enfoca primero el contexto del problema
#    - Clarifica el tipo de análisis necesario
#    - Define mejor el impacto esperado
# ```
#
# Este orden refleja mejor la secuencia lógica de:
# 1. Con qué herramientas contamos
# 2. Qué problema enfrentamos
# 3. Qué queremos hacer al respecto
# 4. Qué resultados esperamos obtener

# %% [markdown]
# # Ecuación de búsqueda (proyecto)
#
# > Proyecto: **Modelo de predicción de rendimiento y calidad de frutos en cultivos de ciclo corto afectados por enfermedades mediante inteligencia artificial**
#
# > Nota práctica: la mayor parte de la literatura indexada está en inglés; por eso la ecuación base está en inglés y al final incluyo términos opcionales en español.
#
# ## Facetas (conceptos macro)
#
# 1. **Tecnología (IA/ML/CV/RS)**
# 2. **Enfermedades/estrés biótico (plant disease)**
# 3. **Predicción / modelado (forecast, estimation)**
# 4. **Resultado (rendimiento y/o calidad de fruto)**
# 5. **Dominio (cultivos de ciclo corto / horticultura)**
#
# ## 1) Ecuación maestra (neutral, para adaptar)
#
# ```
# (
#   "artificial intelligence" OR "machine learning" OR "deep learning" OR
#   "neural network*" OR "convolutional neural network*" OR CNN OR
#   "computer vision" OR "image processing" OR
#   "remote sensing" OR hyperspectral OR multispectral OR "spectral imaging" OR
#   "near infrared" OR "NIR" OR "RGB imaging" OR
#   "random forest" OR "support vector machine" OR SVM
# )
# AND
# (
#   "plant disease*" OR "crop disease*" OR pathogen* OR
#   "fungal disease*" OR "bacterial disease*" OR "viral disease*" OR
#   "disease severity" OR "disease incidence" OR "biotic stress" OR
#   "plant health" OR "disease detection" OR "disease assessment"
# )
# AND
# (
#   predict* OR forecast* OR "yield prediction" OR "yield estimation" OR
#   "quality prediction" OR model* OR estimation OR regression OR
#   "early detection" OR "early warning" OR monitoring
# )
# AND
# (
#   "crop yield" OR "marketable yield" OR "fruit yield" OR
#   "fruit quality" OR "quality assessment" OR "harvest quality" OR
#   firmness OR "soluble solids" OR Brix OR "total soluble solids" OR
#   color OR size OR "fruit weight"
# )
# AND
# (
#   "short-season" OR "short season" OR "short-cycle" OR
#   "annual crop*" OR "vegetable crop*" OR "horticultural crop*" OR horticultur*
# )
# ```
#
# ### Variante menos restrictiva (recomendada para no perder estudios)
#
# Si notas que “short-season/short-cycle” te deja pocos resultados, usa la misma ecuación **sin** la última faceta (cultivo), y luego filtras por tipo de cultivo en el screening:
#
# ```
# [Faceta IA] AND [Faceta Enfermedad] AND [Faceta Predicción] AND [Faceta Resultado]
# ```
#
# ## 2) Versiones por base de datos (lista para copiar/pegar)
#
# ### Scopus (recomendado: `TITLE-ABS-KEY`)
# ```
# TITLE-ABS-KEY(
#   ("artificial intelligence" OR "machine learning" OR "deep learning" OR "neural network*" OR "convolutional neural network*" OR CNN OR "computer vision" OR "image processing" OR "remote sensing" OR hyperspectral OR multispectral OR "spectral imaging" OR "near infrared" OR "NIR" OR "RGB imaging" OR "random forest" OR "support vector machine" OR SVM)
#   AND
#   ("plant disease*" OR "crop disease*" OR pathogen* OR "fungal disease*" OR "bacterial disease*" OR "viral disease*" OR "disease severity" OR "disease incidence" OR "biotic stress" OR "plant health" OR "disease detection" OR "disease assessment")
#   AND
#   (predict* OR forecast* OR "yield prediction" OR "yield estimation" OR "quality prediction" OR model* OR estimation OR regression OR "early detection" OR "early warning" OR monitoring)
#   AND
#   ("crop yield" OR "marketable yield" OR "fruit yield" OR "fruit quality" OR "quality assessment" OR "harvest quality" OR firmness OR "soluble solids" OR Brix OR "total soluble solids" OR color OR size OR "fruit weight")
#   AND
#   ("short-season" OR "short season" OR "short-cycle" OR "annual crop*" OR "vegetable crop*" OR "horticultural crop*" OR horticultur*)
# )
# ```
#
# ### Web of Science (WoS Core Collection)
# ```
# TS=(
#   ("artificial intelligence" OR "machine learning" OR "deep learning" OR "neural network*" OR "convolutional neural network*" OR CNN OR "computer vision" OR "image processing" OR "remote sensing" OR hyperspectral OR multispectral OR "spectral imaging" OR "near infrared" OR "NIR" OR "RGB imaging" OR "random forest" OR "support vector machine" OR SVM)
#   AND
#   ("plant disease*" OR "crop disease*" OR pathogen* OR "fungal disease*" OR "bacterial disease*" OR "viral disease*" OR "disease severity" OR "disease incidence" OR "biotic stress" OR "plant health" OR "disease detection" OR "disease assessment")
#   AND
#   (predict* OR forecast* OR "yield prediction" OR "yield estimation" OR "quality prediction" OR model* OR estimation OR regression OR "early detection" OR "early warning" OR monitoring)
#   AND
#   ("crop yield" OR "marketable yield" OR "fruit yield" OR "fruit quality" OR "quality assessment" OR "harvest quality" OR firmness OR "soluble solids" OR Brix OR "total soluble solids" OR color OR size OR "fruit weight")
#   AND
#   ("short-season" OR "short season" OR "short-cycle" OR "annual crop*" OR "vegetable crop*" OR "horticultural crop*" OR horticultur*)
# )
# ```
#
# ### IEEE Xplore (consulta booleana genérica)
# IEEE Xplore puede ser más sensible a la sintaxis; una versión robusta es usar **All Metadata** o **Abstract** con la misma lógica. Ejemplo (All Metadata):
#
# ```
# ("artificial intelligence" OR "machine learning" OR "deep learning" OR "neural network" OR "computer vision")
# AND
# ("plant disease" OR "crop disease" OR pathogen OR "disease detection")
# AND
# (predict* OR forecast* OR model* OR estimation)
# AND
# (yield OR "fruit quality" OR "quality assessment")
# ```
#
# ### ScienceDirect (consulta booleana genérica)
# ```
# ("artificial intelligence" OR "machine learning" OR "deep learning" OR "neural network*" OR "computer vision" OR "remote sensing" OR hyperspectral OR multispectral OR "near infrared" OR "NIR")
# AND
# ("plant disease*" OR "crop disease*" OR pathogen* OR "disease severity" OR "biotic stress")
# AND
# (predict* OR forecast* OR model* OR estimation OR regression)
# AND
# ("crop yield" OR "fruit quality" OR "quality assessment" OR "harvest quality")
# AND
# ("annual crop*" OR "vegetable crop*" OR "horticultural crop*" OR horticultur*)
# ```
#
# ## 3) Términos opcionales en español (si tu base lo soporta)
#
# En algunas plataformas (o para repositorios regionales) puedes ampliar con:
#
# ```
# ("ciclo corto" OR "cultivo* anual*" OR "horticultura")
# AND
# ("enfermedad* de planta*" OR "enfermedad* de cultivo*" OR "patógeno*")
# AND
# ("predic*" OR "pronóstic*" OR "estimación" OR "modelo")
# AND
# ("rendimiento" OR "producción" OR "calidad de fruto*" OR "calidad")
# AND
# ("inteligencia artificial" OR "aprendizaje automático" OR "visión por computador")
# ```
#
# ## 4) Sugerencias para maximizar “fiabilidad” (sin cambiar la ecuación)
#
# - En Scopus/WoS, prioriza buscar en `TITLE-ABS-KEY` / `TS` y limita a **Article** y **Conference Paper** según tu protocolo.
# - Considera filtrar por áreas: Agriculture/Biological Sciences, Environmental Science, Engineering, Computer Science.
# - Define un rango temporal (p. ej., 2010–2025) y criterios de calidad en el screening (peer-review, dataset real, validación, métricas reportadas).

# %% [markdown]
# # Justificación Lógica del Orden de Facetas
#
# ## Ejemplo de Aplicación
#
# Si tomamos un caso específico orientado a calidad nutricional:
#
# 1. **Tecnología**: Deep Learning y Computer Vision
#    - NT: Hyperspectral Imaging
#    - NT: NIR Spectroscopy
#    - RT: Pattern Recognition
#
# 2. **Enfermedad/Estrés**: Manchas foliares en hojas
#    - BT: Plant Diseases
#    - NT: Fungal Diseases
#    - RT: Nutrient Deficiencies
#
# 3. **Predicción**: Estimación temprana
#    - BT: Predictive Analysis
#    - RT: Real-time Monitoring
#    - RT: Early Detection
#
# 4. **Objeto**: Calidad Nutricional
#    - NT: Macronutrients
#       - NT: Protein Content
#       - NT: Carbohydrate Content
#    - NT: Micronutrients
#       - NT: Vitamin Content
#       - NT: Mineral Content
#    - RT: Organoleptic Properties
#       - NT: Texture
#       - NT: Color
#    - RT: Functional Properties
#       - NT: Bioactive Compounds
#       - NT: Antioxidant Activity
#
# Esta secuencia nos permite entender claramente:
# - **Herramientas**: Tecnologías de imagen hiperespectral y espectroscopía NIR para análisis no destructivo
# - **Problema**: Impacto de enfermedades foliares en la composición nutricional
# - **Predicción**: Detección temprana de cambios en el perfil nutricional
# - **Impacto**: Evaluación de múltiples aspectos de la calidad nutricional:
#   * Contenido de macro y micronutrientes
#   * Propiedades organolépticas asociadas
#   * Compuestos bioactivos y capacidad antioxidante
#
# ### Ecuación de búsqueda resultante:
# ```
# (
#     ("deep learning" OR "computer vision" OR "hyperspectral imaging" OR "NIR spectroscopy")
#     AND
#     ("foliar spot*" OR "leaf spot*" OR "fungal disease*" OR "nutrient deficienc*")
#     AND
#     ("early prediction" OR "early detection" OR "real-time monitoring")
#     AND
#     (
#         ("nutrient* content" OR "nutritional quality")
#         OR
#         ("macronutrient*" OR "protein content" OR "carbohydrate content")
#         OR
#         ("micronutrient*" OR "vitamin*" OR "mineral*")
#         OR
#         ("bioactive compound*" OR "antioxidant activity")
#     )
# )
# ```
#
# Esta estructura jerárquica, basada en tesauros especializados (AGROVOC, NAL, IEEE), permite:
# 1. Capturar la complejidad multidimensional de la calidad nutricional
# 2. Incluir términos relacionados relevantes
# 3. Mantener la coherencia con vocabularios controlados
# 4. Facilitar la expansión o restricción de la búsqueda según necesidades

# %% [markdown]
# # Adaptación para Predicción de Calidad Nutricional
#
# ## Facetas Refinadas para Calidad Nutricional
#
# ### 1. TECNOLOGÍA (Herramientas y Métodos)
# ```
# (
#     "artificial intelligence" OR "machine learning" OR "deep learning"
#     OR "neural network*" OR "computer vision" OR "spectral analysis"
#     OR "near infrared spectroscopy" OR "NIR" OR "hyperspectral imaging"
#     OR "chemical analysis" OR "compositional analysis"
# )
# ```
#
# ### 2. ENFERMEDADES Y FACTORES DE ESTRÉS (Contexto/Problema)
# ```
# (
#     "plant disease*" OR "crop disease*" OR "pathogen*"
#     OR "environmental stress" OR "nutrient deficienc*"
#     OR "physiological disorder*" OR "abiotic stress"
#     OR "water stress" OR "nutritional stress"
# )
# ```
#
# ### 3. PREDICCIÓN Y EVALUACIÓN (Acción/Propósito)
# ```
# (
#     "predict*" OR "forecast*" OR "model*" OR "estimation"
#     OR "assessment" OR "monitoring" OR "analysis"
#     OR "quantification" OR "determination" OR "evaluation"
#     OR "characterization" OR "profiling"
# )
# ```
#
# ### 4. CALIDAD NUTRICIONAL (Objetivo Específico)
# ```
# (
#     ("nutrient* content" OR "nutritional quality" OR "nutritional value")
#     OR
#     ("macronutrient*" OR "protein content" OR "carbohydrate content" OR "lipid content")
#     OR
#     ("micronutrient*" OR "vitamin*" OR "mineral*" OR "trace element*")
#     OR
#     ("organoleptic propert*" OR "sensory quality" OR "food quality")
#     OR
#     ("functional propert*" OR "bioactive compound*" OR "antioxidant*")
#     OR
#     ("moisture content" OR "water activity" OR "dry matter")
# )
# ```
#
# ## Ejemplo de Ecuación Completa (Scopus)
#
# ```
# TITLE-ABS-KEY(
#     (
#         ("artificial intelligence" OR "machine learning" OR "spectral analysis" OR "NIR")
#         AND
#         ("plant disease*" OR "nutrient deficienc*" OR "environmental stress")
#         AND
#         ("predict*" OR "assessment" OR "quantification")
#         AND
#         (
#             ("nutrient* content" OR "nutritional quality")
#             OR
#             ("macronutrient*" OR "micronutrient*")
#             OR
#             ("organoleptic propert*" OR "sensory quality")
#         )
#     )
# )
# ```
#
# ## Aspectos Específicos por Categoría
#
# ### Macronutrientes
# - Proteínas
# - Carbohidratos
# - Lípidos
# - Fibra
#
# ### Micronutrientes
# - Vitaminas
# - Minerales
# - Oligoelementos
# - Antioxidantes
#
# ### Propiedades Organolépticas
# - Textura
# - Sabor
# - Aroma
# - Color
# - Apariencia
#
# ### Propiedades Físico-químicas
# - Contenido de agua
# - Actividad de agua
# - Materia seca
# - pH
# - Acidez
#
# ## Estrategia de Búsqueda Específica
#
# 1. **Por Tipo de Análisis**:
# ```
# ("spectral analysis" OR "NIR" OR "chemical analysis")
# AND
# ("nutrient* content" OR "nutritional quality")
# ```
#
# 2. **Por Componente Específico**:
# ```
# ("machine learning" OR "deep learning")
# AND
# ("predict*" OR "quantification")
# AND
# ("protein content" OR "mineral content" OR "vitamin content")
# ```
#
# 3. **Por Propiedades Organolépticas**:
# ```
# ("computer vision" OR "image analysis" OR "spectral imaging")
# AND
# ("quality assessment" OR "characterization")
# AND
# ("texture" OR "color" OR "appearance")
# ```
#
# ## Consideraciones Importantes
#
# 1. **Métodos de Análisis**:
#    - Técnicas no destructivas (NIR, espectroscopía)
#    - Análisis de imagen (computer vision)
#    - Análisis químicos tradicionales
#
# 2. **Variables de Impacto**:
#    - Enfermedades y patógenos
#    - Estrés ambiental
#    - Deficiencias nutricionales
#    - Condiciones de cultivo
#
# 3. **Aspectos de Calidad**:
#    - Composición nutricional
#    - Propiedades organolépticas
#    - Calidad funcional
#    - Seguridad alimentaria
#
# 4. **Aplicaciones Específicas**:
#    - Monitoreo en tiempo real
#    - Predicción temprana
#    - Evaluación de calidad
#    - Control de procesos

# %% [markdown]
# # Estrategia Multilingüe: Inclusión de Términos en Español
#
# ## Problemática Identificada
# Las ecuaciones de búsqueda actuales **solo contemplan términos en inglés**, lo que excluye:
# - Literatura científica publicada en español
# - Revistas latinoamericanas de calidad
# - Investigación regional relevante en agricultura
# - Tesis y documentos técnicos en español
#
# ## Impacto de la Exclusión
# 1. **Pérdida de contexto regional**: Investigación en cultivos adaptados a condiciones locales
# 2. **Sesgo geográfico**: Predominio de estudios de países angloparlantes
# 3. **Pérdida de innovación local**: Soluciones desarrolladas en contextos hispanohablantes
# 4. **Datos de validación regionales**: Estudios con variedades y condiciones locales
#
# ## Estrategia de Solución
#
# ### Opción 1: Términos Bilingües en la Misma Ecuación (Recomendado)
# Incluir términos en español como sinónimos adicionales en cada faceta.
#
# **Ventajas**:
# - Una sola búsqueda captura ambos idiomas
# - Más eficiente para bases de datos que soportan ambos idiomas (Scopus, WoS)
# - Ecuación más completa
#
# **Desventajas**:
# - Ecuación más larga
# - Puede necesitar ajustes por base de datos
#
# ### Opción 2: Ecuaciones Separadas por Idioma
# Mantener ecuaciones independientes para inglés y español.
#
# **Ventajas**:
# - Ecuaciones más legibles
# - Más fácil de ajustar por idioma
# - Control granular de resultados
#
# **Desventajas**:
# - Requiere dos búsquedas separadas
# - Más trabajo de deduplicación posterior
#
# ## Términos Clave en Español por Faceta
#
# ### Faceta A - Tecnología
# - **Inglés**: artificial intelligence, machine learning, deep learning, computer vision, remote sensing
# - **Español**: inteligencia artificial, aprendizaje automático, aprendizaje profundo, visión por computador, percepción remota, teledetección
#
# ### Faceta B - Enfermedades
# - **Inglés**: plant diseases, crop diseases, pathogen, disease severity
# - **Español**: enfermedades de plantas, enfermedades de cultivos, patógeno, severidad de enfermedad
#
# ### Faceta C - Predicción
# - **Inglés**: prediction, forecasting, estimation, early detection
# - **Español**: predicción, pronóstico, estimación, detección temprana
#
# ### Faceta D - Calidad Nutricional
# - **Inglés**: nutritional quality, nutrient content, macronutrients, vitamins, minerals
# - **Español**: calidad nutricional, contenido nutricional, macronutrientes, vitaminas, minerales
#
# ### Faceta E - Dominio
# - **Inglés**: horticultural crops, vegetable crops, fruit crops
# - **Español**: cultivos hortícolas, cultivos vegetales, cultivos frutales, horticultura
#
# ## Bases de Datos con Mayor Cobertura en Español
#
# 1. **Scopus**: Indexa ~4,000 revistas en español
# 2. **Web of Science**: Incluye SciELO Citation Index (literatura latinoamericana)
# 3. **SciELO**: Base de datos específica de literatura científica latinoamericana
# 4. **Redalyc**: Red de Revistas Científicas de América Latina y el Caribe
#
# ## Recomendación Final
#
# Implementar **Opción 1** para Scopus y WoS (bases principales), y considerar búsquedas complementarias en **SciELO y Redalyc** con términos en español optimizados para esas bases.

# %% [markdown]
# # Bases de Datos Complementarias para Literatura en Español
#
# ## Bases de Datos Especializadas
#
# ### 1. SciELO (Scientific Electronic Library Online)
# **URL**: https://scielo.org
#
# **Cobertura**: ~1,500 revistas de América Latina, España, Portugal y Sudáfrica
# - Mayor cobertura de literatura científica latinoamericana
# - Acceso abierto
# - Fuerte presencia en ciencias agrícolas y biológicas
#
# **Estrategia de búsqueda**:
# - Soporta búsqueda booleana
# - Permite búsqueda en todos los campos o título/resumen
# - Recomendado: usar versión simplificada de la ecuación en español
#
# **Ejemplo de búsqueda en SciELO**:
# ```
# ("inteligencia artificial" OR "aprendizaje automático" OR "visión por computador")
# AND
# ("enfermedades de plantas" OR "enfermedades de cultivos" OR "patógenos")
# AND
# ("predicción" OR "pronóstico" OR "estimación")
# AND
# ("calidad nutricional" OR "contenido nutricional" OR "macronutrientes" OR "micronutrientes")
# AND
# ("cultivos hortícolas" OR "hortalizas" OR "frutales")
# ```
#
# ### 2. Redalyc (Red de Revistas Científicas de América Latina y el Caribe)
# **URL**: https://www.redalyc.org
#
# **Cobertura**: ~1,400 revistas científicas
# - Énfasis en ciencias sociales y naturales
# - Acceso abierto
# - Literatura regional de alta calidad
#
# **Estrategia de búsqueda**:
# - Soporta búsqueda avanzada con operadores booleanos
# - Permite filtrado por área temática
# - Recomendado: combinar términos en español e inglés
#
# ### 3. Dialnet
# **URL**: https://dialnet.unirioja.es
#
# **Cobertura**: Literatura científica hispana
# - Mayor portal bibliográfico de contenido hispano
# - Incluye artículos, tesis, libros
# - Fuerte en España y Latinoamérica
#
# **Áreas relevantes**:
# - Ciencias (Agricultura, Biología)
# - Tecnología
#
# ### 4. LILACS (Literatura Latino-Americana e do Caribe em Ciências da Saúde)
# **URL**: https://lilacs.bvsalud.org
#
# **Cobertura**: Ciencias de la salud
# - Puede incluir estudios de nutrición y calidad alimentaria
# - Base de datos especializada en salud pública
# - Indexa literatura no incluida en bases internacionales
#
# ## Estrategia Integrada de Búsqueda
#
# ### Fase 1: Bases Principales (Inglés + Español)
# 1. **Scopus** - Ecuación bilingüe completa
# 2. **Web of Science** - Ecuación bilingüe + SciELO Citation Index
# 3. **IEEE Xplore** - Predominantemente inglés (términos técnicos)
# 4. **ScienceDirect** - Ecuación simplificada bilingüe
#
# ### Fase 2: Bases Complementarias (Énfasis en Español)
# 5. **SciELO** - Ecuación en español con términos clave en inglés
# 6. **Redalyc** - Ecuación bilingüe adaptada
# 7. **Dialnet** - Búsqueda en español
#
# ### Fase 3: Bases Especializadas (Si aplica)
# 8. **LILACS** - Si el enfoque nutricional lo justifica
# 9. **Repositorios institucionales** - Tesis y documentos técnicos
#
# ## Consideraciones de Deduplicación
#
# Al incluir literatura en español:
# 1. **Herramientas de gestión bibliográfica**: Usar Zotero, Mendeley o EndNote
# 2. **Deduplicación por DOI**: Priorizar DOI como identificador único
# 3. **Deduplicación manual**: Revisar títulos similares en diferentes idiomas
# 4. **Documentar fuente**: Registrar de qué base proviene cada artículo
#
# ## Ejemplo de Registro de Búsqueda
#
# | Base de Datos | Fecha | Ecuación | Idioma | Resultados | Filtros |
# |---------------|-------|----------|--------|------------|---------|
# | Scopus | 2024-12-30 | Ecuación bilingüe completa | EN+ES | 450 | 2010-2025, Article |
# | SciELO | 2024-12-30 | Ecuación adaptada español | ES+EN | 78 | 2010-2025 |
# | Redalyc | 2024-12-30 | Ecuación bilingüe | ES+EN | 45 | 2010-2025 |
#
# ## Ventajas de Incluir Literatura en Español
#
# 1. **Contexto regional**: Estudios con variedades locales y condiciones específicas
# 2. **Innovación local**: Soluciones adaptadas a recursos limitados
# 3. **Datos de validación**: Experimentos en diferentes contextos climáticos
# 4. **Perspectivas diversas**: Enfoques metodológicos complementarios
# 5. **Completitud**: Evita sesgo geográfico/lingüístico
#
# ## Limitaciones a Considerar
#
# 1. **Menor factor de impacto**: Algunas revistas en español tienen menor visibilidad
# 2. **Menos citadas**: Pueden tener menos citas que equivalentes en inglés
# 3. **Calidad variable**: Requiere mayor escrutinio en la evaluación de calidad
# 4. **Duplicación**: Algunos autores publican en ambos idiomas (mismos estudios)
#
# ## Recomendación Final
#
# Para un SLR robusto sobre predicción de calidad nutricional:
# - **Bases principales**: Ecuación bilingüe en Scopus y WoS
# - **Complementar**: SciELO y Redalyc para capturar investigación regional
# - **Criterios de inclusión**: Mismos estándares de calidad independiente del idioma
# - **Extracción de datos**: Preparar formularios bilingües

# %% [markdown]
# # Ejemplos de Ecuaciones Optimizadas por Base de Datos
#
# ## Ecuación para SciELO (Énfasis en Español)
#
# ### Versión Completa (5 Facetas)
# ```
# (
#     ("inteligencia artificial" OR "artificial intelligence" OR "aprendizaje automático" OR
#      "machine learning" OR "aprendizaje profundo" OR "deep learning" OR
#      "visión por computador" OR "computer vision" OR "visión artificial")
#     AND
#     ("enfermedades de plantas" OR "plant diseases" OR "enfermedades de cultivos" OR
#      "crop diseases" OR "patógenos" OR "pathogens" OR "enfermedades fitosanitarias" OR
#      "sanidad vegetal" OR "plant health")
#     AND
#     ("predicción" OR "prediction" OR "pronóstico" OR "forecasting" OR
#      "estimación" OR "estimation" OR "detección temprana" OR "early detection")
#     AND
#     ("calidad nutricional" OR "nutritional quality" OR "contenido nutricional" OR
#      "nutrient content" OR "composición nutricional" OR "nutritional composition" OR
#      "macronutrientes" OR "macronutrients" OR "micronutrientes" OR "micronutrients" OR
#      "vitaminas" OR "vitamins" OR "minerales" OR "minerals" OR
#      "compuestos bioactivos" OR "bioactive compounds" OR "fitoquímicos" OR "phytochemicals")
#     AND
#     ("cultivos hortícolas" OR "horticultural crops" OR "hortalizas" OR "vegetable crops" OR
#      "cultivos frutales" OR "fruit crops" OR "horticultura" OR "horticulture" OR
#      "ciclo corto" OR "short-cycle" OR "cultivos anuales" OR "annual crops")
# )
# ```
#
# ### Versión Simplificada (Para mayor recall)
# ```
# ("inteligencia artificial" OR "machine learning" OR "visión por computador")
# AND
# ("enfermedades" OR "patógenos" OR "sanidad")
# AND
# ("calidad nutricional" OR "nutrientes" OR "composición")
# AND
# ("hortalizas" OR "frutales" OR "horticultura")
# ```
#
# ## Ecuación para Redalyc
#
# ### Recomendación: Términos Clave Bilingües
# ```
# TITLE-ABS-KEY(
#     ("inteligencia artificial" OR "artificial intelligence" OR "IA" OR "AI")
#     AND
#     ("enfermedades de plantas" OR "plant disease*" OR "fitosanidad")
#     AND
#     ("calidad nutricional" OR "nutritional quality" OR "nutrientes" OR "nutrients")
#     AND
#     ("cultivos" OR "crops" OR "horticultura" OR "horticulture")
# )
# ```
#
# ## Ecuación para Dialnet
#
# ### Búsqueda Avanzada (Español prioritario)
# ```
# Todos los campos:
# ("inteligencia artificial" OR "aprendizaje automático" OR "visión artificial")
#
# Y
#
# Todos los campos:
# ("enfermedades de plantas" OR "enfermedades de cultivos" OR "fitosanitarias")
#
# Y
#
# Todos los campos:
# ("calidad nutricional" OR "composición nutricional" OR "nutrientes")
#
# Y
#
# Todos los campos:
# ("hortícolas" OR "hortalizas" OR "frutales" OR "horticultura")
#
# Filtros:
# - Área temática: Ciencias → Agricultura
# - Tipo de documento: Artículos de revista
# - Años: 2010-2025
# ```
#
# ## Comparación de Estrategias
#
# | Característica | Scopus/WoS | SciELO | Redalyc | Dialnet |
# |----------------|------------|---------|---------|---------|
# | **Prioridad idioma** | Inglés > Español | Equilibrado | Equilibrado | Español |
# | **Términos técnicos** | Mantener EN | EN + ES | EN + ES | Principalmente ES |
# | **Sinónimos** | Exhaustivos | Moderados | Moderados | Selectivos |
# | **Longitud ecuación** | Completa | Moderada | Moderada | Simplificada |
# | **Operadores** | AND/OR/NOT | AND/OR | AND/OR | AND/OR (campo) |
#
# ## Ejemplo de Flujo de Trabajo
#
# ### Paso 1: Búsqueda en Bases Principales
# ```python
# # Scopus y WoS
# ecuacion_bilingue_completa = """
# TITLE-ABS-KEY(
#     (...términos IA en EN+ES...)
#     AND (...enfermedades EN+ES...)
#     AND (...predicción EN+ES...)
#     AND (...nutrición EN+ES...)
#     AND (...cultivos EN+ES...)
# )
# """
# # Resultados esperados: 400-600 documentos
# ```
#
# ### Paso 2: Complementar con SciELO
# ```python
# # SciELO - Énfasis español
# ecuacion_scielo = """
# (inteligencia artificial OR machine learning OR visión por computador)
# AND
# (enfermedades de plantas OR patógenos OR fitosanidad)
# AND
# (calidad nutricional OR contenido nutricional OR nutrientes)
# AND
# (hortalizas OR frutales OR cultivos hortícolas)
# """
# # Resultados esperados: 50-100 documentos adicionales
# ```
#
# ### Paso 3: Refinar con Redalyc
# ```python
# # Redalyc - Balance EN/ES
# ecuacion_redalyc = """
# Similar a SciELO pero ajustando términos según interfaz
# """
# # Resultados esperados: 30-60 documentos adicionales
# ```
#
# ### Paso 4: Capturar Literatura Gris
# ```python
# # Dialnet, repositorios institucionales
# ecuacion_dialnet = """
# Términos principalmente en español
# Incluir tesis y documentos técnicos relevantes
# """
# # Resultados esperados: 20-40 documentos adicionales
# ```
#
# ## Matriz de Decisión: ¿Cuándo usar cada base?
#
# | Si buscas... | Usa... | Porque... |
# |--------------|--------|-----------|
# | Literatura mainstream | Scopus/WoS | Mayor cobertura internacional |
# | Estudios regionales LA | SciELO | Especializada en región |
# | Casos de estudio locales | Redalyc | Contextos específicos |
# | Tesis/documentos técnicos | Dialnet | Literatura gris hispana |
# | Métodos de IA | IEEE | Especializada en tecnología |
# | Aspectos nutricionales | PubMed/LILACS | Ciencias de la salud |
#
# ## Checklist de Implementación
#
# - [ ] Definir ecuación base bilingüe (EN+ES)
# - [ ] Adaptar ecuación para cada base de datos
# - [ ] Documentar fechas y resultados por base
# - [ ] Exportar resultados en formato compatible (RIS/BibTeX)
# - [ ] Importar a gestor bibliográfico (Zotero/Mendeley)
# - [ ] Ejecutar deduplicación automática (por DOI/título)
# - [ ] Deduplicación manual de registros similares
# - [ ] Screening por título/resumen (criterios bilingües)
# - [ ] Evaluación de texto completo
# - [ ] Extracción de datos (formulario bilingüe)
#
# ## Recursos Adicionales
#
# ### Tutoriales de Búsqueda
# - **SciELO**: https://scielo.org/es/sobre-scielo/metodologia-scielo/
# - **Redalyc**: https://www.redalyc.org/ayuda.oa
# - **Dialnet**: https://dialnet.unirioja.es/ayuda/ayuda
#
# ### Herramientas de Apoyo
# - **Zotero**: Plugin para importación automática
# - **Litmaps**: Visualización de redes de citación
# - **Rayyan**: Screening colaborativo bilingüe
# - **Covidence**: Gestión de SLR con soporte multiidioma

# %% [markdown]
# # Jerarquización de Conceptos según Tesauros
#
# ## 1. TECNOLOGÍA (IEEE/ACM)
# ```
# ➤ Artificial Intelligence
#    ├─ Machine Learning
#    │  ├─ Deep Learning
#    │  │  ├─ Convolutional Neural Networks
#    │  │  ├─ Recurrent Neural Networks
#    │  │  └─ Transfer Learning
#    │  ├─ Supervised Learning
#    │  │  ├─ Classification
#    │  │  └─ Regression
#    │  └─ Unsupervised Learning
#    │     ├─ Clustering
#    │     └─ Dimensionality Reduction
#    │
#    ├─ Computer Vision
#    │  ├─ Image Processing
#    │  │  ├─ Feature Extraction
#    │  │  ├─ Segmentation
#    │  │  └─ Pattern Recognition
#    │  └─ Spectral Analysis
#    │     ├─ Hyperspectral Imaging
#    │     ├─ NIR Spectroscopy
#    │     └─ Multispectral Analysis
#    │
#    └─ Data Analytics
#       ├─ Predictive Analytics
#       ├─ Statistical Analysis
#       └─ Time Series Analysis
# ```
#
# ## 2. ENFERMEDADES Y ESTRÉS (NAL/AGROVOC)
# ```
# ➤ Plant Health Issues
#    ├─ Plant Diseases
#    │  ├─ Fungal Diseases
#    │  ├─ Bacterial Diseases
#    │  ├─ Viral Diseases
#    │  └─ Disease Progression
#    │
#    ├─ Physiological Disorders
#    │  ├─ Nutrient Deficiencies
#    │  │  ├─ Macronutrient Deficiencies
#    │  │  └─ Micronutrient Deficiencies
#    │  └─ Environmental Stress
#    │
#    └─ Stress Factors
#       ├─ Abiotic Stress
#       │  ├─ Water Stress
#       │  ├─ Temperature Stress
#       │  └─ Light Stress
#       └─ Biotic Stress
#          ├─ Pest Damage
#          └─ Pathogen Infection
# ```
#
# ## 3. PREDICCIÓN Y EVALUACIÓN (IEEE/NAL)
# ```
# ➤ Predictive Analysis
#    ├─ Modeling Methods
#    │  ├─ Mathematical Models
#    │  ├─ Statistical Models
#    │  └─ Machine Learning Models
#    │
#    ├─ Prediction Types
#    │  ├─ Early Detection
#    │  ├─ Real-time Monitoring
#    │  └─ Forecasting
#    │
#    └─ Assessment Methods
#       ├─ Quantitative Analysis
#       │  ├─ Chemical Analysis
#       │  └─ Physical Analysis
#       └─ Qualitative Analysis
#          ├─ Visual Assessment
#          └─ Sensory Evaluation
# ```
#
# ## 4. CALIDAD NUTRICIONAL (NAL/AGROVOC)
# ```
# ➤ Nutritional Quality
#    ├─ Macronutrients
#    │  ├─ Proteins
#    │  │  ├─ Amino Acids
#    │  │  └─ Protein Content
#    │  ├─ Carbohydrates
#    │  │  ├─ Simple Sugars
#    │  │  └─ Complex Carbohydrates
#    │  └─ Lipids
#    │     ├─ Fatty Acids
#    │     └─ Fat Content
#    │
#    ├─ Micronutrients
#    │  ├─ Vitamins
#    │  │  ├─ Water-soluble
#    │  │  └─ Fat-soluble
#    │  └─ Minerals
#    │     ├─ Major Minerals
#    │     └─ Trace Elements
#    │
#    ├─ Organoleptic Properties
#    │  ├─ Physical Properties
#    │  │  ├─ Texture
#    │  │  ├─ Color
#    │  │  └─ Appearance
#    │  └─ Chemical Properties
#    │     ├─ Flavor
#    │     ├─ Aroma
#    │     └─ Taste
#    │
#    └─ Functional Properties
#       ├─ Bioactive Compounds
#       │  ├─ Antioxidants
#       │  └─ Phytochemicals
#       └─ Physical Characteristics
#          ├─ Water Activity
#          └─ Moisture Content
# ```
#
# ## Relaciones entre Niveles (Basado en Tesauros)
#
# ### Relaciones Verticales (BT/NT)
# - BT (Broader Term): Término más amplio
# - NT (Narrower Term): Término más específico
#
# ### Relaciones Horizontales (RT)
# - RT (Related Term): Términos relacionados
# - UF (Used For): Términos alternativos
#
# ## Códigos de Búsqueda por Nivel
#
# ### Nivel 1 (Términos más Amplios)
# ```
# ("artificial intelligence" OR "plant health" OR "prediction" OR "nutritional quality")
# ```
#
# ### Nivel 2 (Términos Específicos)
# ```
# ("machine learning" OR "plant disease*" OR "predictive model*" OR "nutrient* content")
# ```
#
# ### Nivel 3 (Términos muy Específicos)
# ```
# ("deep learning" OR "nutrient deficienc*" OR "early detection" OR "protein content")
# ```
#
# ## Notas sobre Fuentes de Tesauros
#
# 1. **IEEE Thesaurus**
#    - Términos técnicos y de IA
#    - Métodos computacionales
#    - Técnicas de análisis
#
# 2. **NAL Thesaurus**
#    - Términos agrícolas
#    - Enfermedades de plantas
#    - Aspectos nutricionales
#
# 3. **AGROVOC**
#    - Términos agrícolas multilingües
#    - Aspectos de calidad
#    - Propiedades nutricionales
#
# 4. **ACM Computing Classification**
#    - Métodos de IA
#    - Técnicas de análisis
#    - Procesamiento de datos

# %% [markdown]
# # Construcción de Ecuaciones de Búsqueda usando Tesauros Estandarizados
#
# Este notebook demuestra cómo usar la clase `ThesaurusBuilder` para construir ecuaciones de búsqueda que cumplan con los estándares de tesauros.

# %% [markdown]
# ## Relaciones Básicas en un Tesauro
#
# Las relaciones fundamentales en un tesauro estandarizado son:
#
# 1. **BT (Broader Term / Término Más Amplio)**
#    - Indica una relación jerárquica hacia arriba
#    - El término BT es más general que el término actual
#    - Ejemplo: "machine learning" BT "artificial intelligence"
#
# 2. **NT (Narrower Term / Término Más Específico)**
#    - Indica una relación jerárquica hacia abajo
#    - El término NT es más específico que el término actual
#    - Ejemplo: "deep learning" NT "machine learning"
#
# 3. **RT (Related Term / Término Relacionado)**
#    - Indica una asociación entre términos que no es jerárquica
#    - Los términos RT tienen una relación semántica o conceptual
#    - Ejemplo: "supervised learning" RT "unsupervised learning"
#
# 4. **UF (Used For / Usado Por)**
#    - Indica que el término actual es el preferido
#    - Los términos UF son sinónimos o variantes no preferidas
#    - Ejemplo: "artificial intelligence" UF "AI"
#
# 5. **USE (Usar)**
#    - Indica que existe un término preferido
#    - Dirige desde un término no preferido al término autorizado
#    - Ejemplo: "AI" USE "artificial intelligence"
#
# 6. **SN (Scope Note / Nota de Alcance)**
#    - No es una relación, sino una nota explicativa
#    - Define el significado y uso del término en el tesauro
#    - Ejemplo: SN "Systems that can learn from data" para "machine learning"
#
# Estas relaciones son bidireccionales:
# - Si A es BT de B, entonces B es NT de A
# - Si A tiene UF B, entonces B tiene USE A
# - Si A es RT de B, entonces B es RT de A
#
# ### Fuentes y Estándares
#
# Esta estructura de relaciones está basada en estándares internacionales y documentación especializada:
#
# 1. **ISO 25964-1:2011** - "Information and documentation — Thesauri and interoperability with other vocabularies — Part 1: Thesauri for information retrieval"
#    - Principal estándar internacional para la construcción de tesauros
#    - Define la estructura y relaciones básicas
#    - Establece las buenas prácticas para el control de vocabulario
#
# 2. **ANSI/NISO Z39.19-2005 (R2010)** - "Guidelines for the Construction, Format, and Management of Monolingual Controlled Vocabularies"
#    - Guía americana para la construcción de vocabularios controlados
#    - Define las relaciones semánticas y su uso
#    - Establece principios para la gestión de tesauros
#
# 3. **UNESCO Thesaurus Guidelines** (2005)
#    - Guía práctica para la construcción de tesauros multilingües
#    - Define la implementación de relaciones jerárquicas y asociativas
#    - Proporciona ejemplos de uso en contextos internacionales
#
# 4. **ASIS&T Thesaurus Construction Guidelines** - American Society for Information Science and Technology
#    - Directrices para la construcción y mantenimiento de tesauros
#    - Define las mejores prácticas para establecer relaciones
#    - Proporciona ejemplos prácticos de implementación
#
# 5. **The Thesaurus: Review, Renaissance, and Revision** (2004)
#    - Autores: Sandra K. Roe y Alan R. Thomas
#    - Analiza la evolución y modernización de los tesauros
#    - Discute la implementación práctica de las relaciones
#
# Estas fuentes establecen los estándares internacionales que aseguran:
# - Consistencia en la estructura del tesauro
# - Interoperabilidad entre diferentes sistemas
# - Calidad en el control del vocabulario
# - Correcta gestión de las relaciones semánticas

# %% [markdown]
# ## Tesauros más relevantes
#
# Para **predicción de rendimiento y calidad de frutos en cultivos de ciclo corto afectados por enfermedades mediante IA**, lo más consistente es combinar tesauros por dominio:
#
# 1. **IEEE Thesaurus** (tecnología)
#    - Para: *Artificial intelligence, Machine learning, Deep learning, Computer vision, Image processing, Remote sensing, Neural networks, Predictive analytics*.
#    - Uso: cubrir métodos/algoritmos, visión por computador, sensores y análisis de datos.
#
# 2. **AGROVOC (FAO)** (agricultura)
#    - Para: *cultivos/horticultura*, *enfermedades de plantas*, *producción/rendimiento*, *calidad* (incluida calidad nutricional).
#    - Uso: normalizar el vocabulario agrícola y evitar variaciones locales de términos.
#
# 3. **NAL Agricultural Thesaurus (USDA)** (agricultura + patología + calidad)
#    - Para: términos finos de *plant diseases*, *disease severity*, *crop yield*, *fruit quality* y atributos (p. ej. sólidos solubles, firmeza).
#    - Además: muy útil para *nutritional quality* y variables de matriz nutricional (macro/micro/minerales/vitaminas).
#
# 4. **CAB Thesaurus (CABI)** (ciencias de la vida / fitopatología)
#    - Para: patógenos, síntomas, tipos de enfermedad, diagnóstico/detección.
#    - Uso: muy útil para capturar literatura de fitopatología aplicada.
#
# 5. **ACM Computing Classification System (ACM CCS)** (computación, complementario a IEEE)
#    - Para: taxonomía de métodos (aprendizaje supervisado, visión por computador, etc.).
#
# > Recomendación práctica: usa estos tesauros como **fuente** para elegir *términos preferidos* y *sinónimos* (UF/USE). En el builder puedes mantener el término preferido y agregar sinónimos como `USE`.
#
# ### Facetas sugeridas (con términos candidatos)
#
# A continuación dejo un set de términos **candidatos** (en inglés) para cargar al constructor. La idea es que ajustes los labels al “término preferido” exacto según IEEE/AGROVOC/NAL/CAB cuando lo verifiques.
#
# #### Faceta A — Tecnología (IEEE/ACM)
# - Preferidos: artificial intelligence; machine learning; deep learning; neural networks; computer vision; image processing; remote sensing; hyperspectral imaging; multispectral imaging; near infrared spectroscopy; time series analysis; predictive analytics.
# - Sinónimos (UF): AI; CNN; RNN; transformer; SVM; support vector machine; random forest; UAV; drone; RGB imaging; spectral imaging; NIR.
#
# #### Faceta B — Enfermedad/estrés biótico (AGROVOC/NAL/CAB)
# - Preferidos: plant diseases; crop disease; plant pathogens; disease severity; disease incidence; disease detection; disease diagnosis; plant health.
# - Más específicos (NT): fungal diseases; bacterial diseases; viral diseases; leaf spot diseases; blight; rust; powdery mildew; downy mildew; anthracnose; wilt.
#
# #### Faceta C — Predicción / modelado (IEEE + NAL)
# - Preferidos: prediction; forecasting; estimation; regression; classification; early detection; monitoring; decision support.
# - Sinónimos (UF): predict*; forecast*; yield prediction; yield estimation; quality prediction; quality assessment.
#
# #### Faceta D — Resultado (producción/rendimiento + calidad) (AGROVOC/NAL)
# - Preferidos: crop production; crop yield; fruit yield; marketable yield; fruit quality; harvest quality; quality assessment.
# - Atributos de calidad (RT/NT según convenga): firmness; soluble solids; total soluble solids; Brix; titratable acidity; color; size; fruit weight; shelf life; maturity index.
# - **Matriz nutricional / calidad nutricional (NT recomendado dentro de esta misma faceta)**: nutritional quality; nutritional value; nutrient content; nutritional composition.
#   - Macronutrientes: protein content; carbohydrate content; lipid/fat content; dietary fiber.
#   - Micronutrientes/minerales: vitamins; vitamin C/ascorbic acid; minerals; trace elements; iron; zinc; calcium; potassium.
#   - Fitonutrientes/fitoquímicos: phytochemicals; phenolic compounds/polyphenols (TPC); flavonoids (TFC); anthocyanins; carotenoids; lycopene; antioxidant activity/capacity.
#
# #### Faceta E — Dominio (cultivos de ciclo corto / horticultura) (AGROVOC/NAL)
# - Preferidos: horticultural crops; vegetable crops; fruit crops; annual crops.
# - Opcional (si necesitas reforzar “ciclo corto”): short-season; short cycle; short-cycle; short duration.
#
# Si quieres, puedo ayudarte a **aterrizar** esta lista a 2–3 cultivos concretos (p. ej. tomate/fresa/pimentón) sin volver la ecuación demasiado restrictiva.

# %%
# Tesauro por facetas (proyecto): IA + enfermedades + predicción + NUTRICIÓN (+ rendimiento opcional)
# VERSION BILINGÜE (Inglés + Español)
from typing import Optional, Sequence
from thesaurus_builder import ThesaurusBuilder, RelationType

def add_preferred_with_synonyms(
    builder: ThesaurusBuilder,
    preferred: str,
    synonyms: Optional[Sequence[str]] = None,
    scope_note: Optional[str] = None,
):
    term = builder.add_term(preferred, scope_note=scope_note, is_preferred=True)
    for syn in (synonyms or []):
        syn_term = builder.add_term(syn, is_preferred=False)
        syn_term.add_relation(RelationType.USE, term)
    return term


builder = ThesaurusBuilder()

# Faceta A — Tecnología (IEEE/ACM) - BILINGÜE
ai = add_preferred_with_synonyms(
    builder,
    "artificial intelligence",
    synonyms=["AI", "inteligencia artificial", "IA"],
    scope_note="Computational methods that emulate or augment intelligent behavior",
)

ml = add_preferred_with_synonyms(
    builder, 
    "machine learning", 
    synonyms=["aprendizaje automático", "aprendizaje de máquina", "machine-learning"]
)
ml.add_relation(RelationType.BT, ai)

dl = add_preferred_with_synonyms(
    builder, 
    "deep learning", 
    synonyms=["aprendizaje profundo", "deep-learning"]
)
dl.add_relation(RelationType.BT, ml)

cnn = add_preferred_with_synonyms(
    builder, 
    "convolutional neural networks", 
    synonyms=["CNN", "redes neuronales convolucionales"]
)
cnn.add_relation(RelationType.BT, dl)

rnn = add_preferred_with_synonyms(
    builder, 
    "recurrent neural networks", 
    synonyms=["RNN", "redes neuronales recurrentes"]
)
rnn.add_relation(RelationType.BT, dl)

transformers = add_preferred_with_synonyms(
    builder, 
    "transformers", 
    synonyms=["transformer model*", "transformadores"]
)
transformers.add_relation(RelationType.BT, dl)

cv = add_preferred_with_synonyms(
    builder, 
    "computer vision", 
    synonyms=["visión por computador", "visión artificial", "visión computacional"]
)
cv.add_relation(RelationType.BT, ai)

img_proc = add_preferred_with_synonyms(
    builder, 
    "image processing", 
    synonyms=["procesamiento de imágenes", "procesamiento de imagen"]
)
img_proc.add_relation(RelationType.BT, cv)

remote_sensing = add_preferred_with_synonyms(
    builder, 
    "remote sensing", 
    synonyms=["teledetección", "percepción remota", "sensores remotos"]
)
remote_sensing.add_relation(RelationType.RT, cv)

hyperspectral = add_preferred_with_synonyms(
    builder, 
    "hyperspectral imaging", 
    synonyms=["imagen hiperespectral", "imágenes hiperespectrales"]
)
hyperspectral.add_relation(RelationType.BT, remote_sensing)

multispectral = add_preferred_with_synonyms(
    builder, 
    "multispectral imaging", 
    synonyms=["imagen multiespectral", "imágenes multiespectrales"]
)
multispectral.add_relation(RelationType.BT, remote_sensing)

nir = add_preferred_with_synonyms(
    builder, 
    "near infrared spectroscopy", 
    synonyms=["NIR", "espectroscopía de infrarrojo cercano", "infrarrojo cercano"]
)
nir.add_relation(RelationType.RT, hyperspectral)

svm = add_preferred_with_synonyms(
    builder, 
    "support vector machine", 
    synonyms=["SVM", "máquinas de soporte vectorial", "máquina de vectores de soporte"]
)
svm.add_relation(RelationType.RT, ml)

rf = add_preferred_with_synonyms(
    builder, 
    "random forest", 
    synonyms=["bosques aleatorios", "random-forest"]
)
rf.add_relation(RelationType.RT, ml)

# Faceta B — Enfermedad/estrés (AGROVOC/NAL/CAB) - BILINGÜE
plant_health = add_preferred_with_synonyms(
    builder, 
    "plant health", 
    synonyms=["salud vegetal", "sanidad vegetal", "fitosanidad"]
)

plant_diseases = add_preferred_with_synonyms(
    builder, 
    "plant diseases", 
    synonyms=["plant disease*", "crop disease*", "enfermedades de plantas", 
              "enfermedades vegetales", "enfermedades de cultivos", "enfermedades fitosanitarias"]
)
plant_diseases.add_relation(RelationType.BT, plant_health)

pathogens = add_preferred_with_synonyms(
    builder, 
    "plant pathogens", 
    synonyms=["pathogen*", "patógenos", "patógeno*", "agentes patógenos"]
)
pathogens.add_relation(RelationType.RT, plant_diseases)

fungal = add_preferred_with_synonyms(
    builder, 
    "fungal diseases", 
    synonyms=["enfermedades fúngicas", "enfermedades fungosas", "hongos fitopatógenos"]
)
fungal.add_relation(RelationType.BT, plant_diseases)

bacterial = add_preferred_with_synonyms(
    builder, 
    "bacterial diseases", 
    synonyms=["enfermedades bacterianas", "bacteriosis"]
)
bacterial.add_relation(RelationType.BT, plant_diseases)

viral = add_preferred_with_synonyms(
    builder, 
    "viral diseases", 
    synonyms=["enfermedades virales", "virosis"]
)
viral.add_relation(RelationType.BT, plant_diseases)

disease_severity = add_preferred_with_synonyms(
    builder, 
    "disease severity", 
    synonyms=["severidad de enfermedad", "severidad de la enfermedad", "gravedad de enfermedad"]
)
disease_severity.add_relation(RelationType.RT, plant_diseases)

disease_incidence = add_preferred_with_synonyms(
    builder, 
    "disease incidence", 
    synonyms=["incidencia de enfermedad", "incidencia de la enfermedad"]
)
disease_incidence.add_relation(RelationType.RT, plant_diseases)

disease_detection = add_preferred_with_synonyms(
    builder, 
    "disease detection", 
    synonyms=["detección de enfermedades", "diagnóstico de enfermedades"]
)
disease_detection.add_relation(RelationType.RT, plant_diseases)

# Faceta C — Predicción/modelado - BILINGÜE
prediction = add_preferred_with_synonyms(
    builder, 
    "prediction", 
    synonyms=["forecasting", "estimation", "predicción", "pronóstico", 
              "estimación", "estimado", "forecast*", "predict*"]
)

early_detection = add_preferred_with_synonyms(
    builder, 
    "early detection", 
    synonyms=["early warning", "detección temprana", "detección precoz", "alerta temprana"]
)
early_detection.add_relation(RelationType.BT, prediction)

monitoring = add_preferred_with_synonyms(
    builder, 
    "monitoring", 
    synonyms=["real-time monitoring", "monitoreo", "monitorización", "seguimiento"]
)
monitoring.add_relation(RelationType.RT, early_detection)

regression = add_preferred_with_synonyms(
    builder, 
    "regression", 
    synonyms=["regresión", "análisis de regresión"]
)
regression.add_relation(RelationType.RT, prediction)

classification = add_preferred_with_synonyms(
    builder, 
    "classification", 
    synonyms=["clasificación"]
)
classification.add_relation(RelationType.RT, prediction)

# Resultado auxiliar (rendimiento/calidad general) — BILINGÜE
crop_production = add_preferred_with_synonyms(
    builder, 
    "crop production", 
    synonyms=["producción de cultivos", "producción agrícola"]
)

crop_yield = add_preferred_with_synonyms(
    builder, 
    "crop yield", 
    synonyms=["yield", "rendimiento", "rendimiento de cultivo", "producción"]
)
crop_yield.add_relation(RelationType.BT, crop_production)

fruit_yield = add_preferred_with_synonyms(
    builder, 
    "fruit yield", 
    synonyms=["rendimiento de fruto", "producción de fruto"]
)
fruit_yield.add_relation(RelationType.BT, crop_yield)

marketable_yield = add_preferred_with_synonyms(
    builder, 
    "marketable yield", 
    synonyms=["rendimiento comercial", "producción comercializable"]
)
marketable_yield.add_relation(RelationType.RT, crop_yield)

fruit_quality = add_preferred_with_synonyms(
    builder, 
    "fruit quality", 
    synonyms=["harvest quality", "quality assessment", "calidad de fruto", 
              "calidad del fruto", "calidad de cosecha"]
)
fruit_quality.add_relation(RelationType.BT, crop_production)

# Calidad fisicoquímica/organoléptica (típica en calidad de fruto)
brix = add_preferred_with_synonyms(
    builder, 
    "total soluble solids", 
    synonyms=["Brix", "soluble solids", "sólidos solubles", "sólidos solubles totales", "grados Brix"]
)
brix.add_relation(RelationType.RT, fruit_quality)

firmness = add_preferred_with_synonyms(
    builder, 
    "firmness", 
    synonyms=["firmeza", "textura"]
)
firmness.add_relation(RelationType.RT, fruit_quality)

color = add_preferred_with_synonyms(
    builder, 
    "color", 
    synonyms=["coloración"]
)
color.add_relation(RelationType.RT, fruit_quality)

fruit_weight = add_preferred_with_synonyms(
    builder, 
    "fruit weight", 
    synonyms=["peso del fruto", "peso de fruto"]
)
fruit_weight.add_relation(RelationType.RT, fruit_quality)

# Faceta D (principal) — Matriz nutricional / calidad nutricional - BILINGÜE
nutritional_quality = add_preferred_with_synonyms(
    builder,
    "nutritional quality",
    synonyms=[
        "nutritional value",
        "nutritional composition",
        "nutrient content",
        "nutritional profile",
        "nutrient profile",
        "food composition",
        "calidad nutricional",
        "valor nutricional",
        "composición nutricional",
        "contenido nutricional",
        "perfil nutricional",
        "valor nutritivo",
    ],
)

# Para no perder estudios que usen lenguaje de "fruit quality" sin decir nutrición
fruit_quality.add_relation(RelationType.RT, nutritional_quality)

# Términos de nutrición frecuentes en Scopus
proximate_composition = add_preferred_with_synonyms(
    builder,
    "proximate composition",
    synonyms=["proximate analysis", "chemical composition", "composición proximal", 
              "análisis proximal", "composición química"],
)
proximate_composition.add_relation(RelationType.BT, nutritional_quality)

nutritional_analysis = add_preferred_with_synonyms(
    builder,
    "nutritional analysis",
    synonyms=["nutrient analysis", "análisis nutricional", "análisis de nutrientes"],
)
nutritional_analysis.add_relation(RelationType.BT, nutritional_quality)

macronutrients = add_preferred_with_synonyms(
    builder, 
    "macronutrients", 
    synonyms=["macronutrientes"]
)
macronutrients.add_relation(RelationType.BT, nutritional_quality)

protein = add_preferred_with_synonyms(
    builder, 
    "protein content", 
    synonyms=["protein", "contenido de proteína", "proteínas", "contenido proteico"]
)
protein.add_relation(RelationType.BT, macronutrients)

carbohydrate = add_preferred_with_synonyms(
    builder, 
    "carbohydrate content", 
    synonyms=["carbohydrate*", "sugar content", "contenido de carbohidratos", 
              "carbohidratos", "hidratos de carbono", "azúcares"]
)
carbohydrate.add_relation(RelationType.BT, macronutrients)

lipid = add_preferred_with_synonyms(
    builder, 
    "lipid content", 
    synonyms=["fat content", "lipid*", "contenido de lípidos", "lípidos", 
              "grasas", "contenido graso"]
)
lipid.add_relation(RelationType.BT, macronutrients)

fiber = add_preferred_with_synonyms(
    builder, 
    "dietary fiber", 
    synonyms=["fibre", "fiber content", "fibra dietética", "fibra alimentaria", "fibra"]
)
fiber.add_relation(RelationType.BT, macronutrients)

micronutrients = add_preferred_with_synonyms(
    builder, 
    "micronutrients", 
    synonyms=["micronutrientes"]
)
micronutrients.add_relation(RelationType.BT, nutritional_quality)

vitamins = add_preferred_with_synonyms(
    builder, 
    "vitamins", 
    synonyms=["vitamin content", "vitaminas", "contenido de vitaminas", "contenido vitamínico"]
)
vitamins.add_relation(RelationType.BT, micronutrients)

vitamin_c = add_preferred_with_synonyms(
    builder, 
    "vitamin C", 
    synonyms=["ascorbic acid", "vitamina C", "ácido ascórbico"]
)
vitamin_c.add_relation(RelationType.BT, vitamins)

minerals = add_preferred_with_synonyms(
    builder, 
    "minerals", 
    synonyms=["mineral content", "mineral composition", "minerales", 
              "contenido mineral", "contenido de minerales", "composición mineral"]
)
minerals.add_relation(RelationType.BT, micronutrients)

trace_elements = add_preferred_with_synonyms(
    builder, 
    "trace elements", 
    synonyms=["microminerals", "oligoelementos", "elementos traza", "microminerales"]
)
trace_elements.add_relation(RelationType.BT, minerals)

iron = add_preferred_with_synonyms(
    builder, 
    "iron", 
    synonyms=["Fe", "hierro"]
)
iron.add_relation(RelationType.BT, minerals)

zinc = add_preferred_with_synonyms(
    builder, 
    "zinc", 
    synonyms=["Zn", "cinc"]
)
zinc.add_relation(RelationType.BT, minerals)

calcium = add_preferred_with_synonyms(
    builder, 
    "calcium", 
    synonyms=["Ca", "calcio"]
)
calcium.add_relation(RelationType.BT, minerals)

potassium = add_preferred_with_synonyms(
    builder, 
    "potassium", 
    synonyms=["K", "potasio"]
)
potassium.add_relation(RelationType.BT, minerals)

phytochemicals = add_preferred_with_synonyms(
    builder, 
    "phytochemicals", 
    synonyms=["phytonutrients", "bioactive compounds", "fitoquímicos", 
              "fitonutrientes", "compuestos bioactivos"]
)
phytochemicals.add_relation(RelationType.BT, nutritional_quality)

phenolic_compounds = add_preferred_with_synonyms(
    builder,
    "phenolic compounds",
    synonyms=["polyphenols", "phenolic content", "total phenolic content", "TPC",
              "compuestos fenólicos", "fenoles", "polifenoles", "contenido fenólico", 
              "contenido de fenoles totales"],
)
phenolic_compounds.add_relation(RelationType.BT, phytochemicals)

flavonoids = add_preferred_with_synonyms(
    builder,
    "flavonoids",
    synonyms=["flavonoid content", "total flavonoid content", "TFC",
              "flavonoides", "contenido de flavonoides"],
)
flavonoids.add_relation(RelationType.BT, phytochemicals)

anthocyanins = add_preferred_with_synonyms(
    builder, 
    "anthocyanins", 
    synonyms=["anthocyanin content", "antocianinas", "antocianos", "contenido de antocianinas"]
)
anthocyanins.add_relation(RelationType.BT, phytochemicals)

carotenoids = add_preferred_with_synonyms(
    builder, 
    "carotenoids", 
    synonyms=["carotenoid content", "carotenoides", "contenido de carotenoides"]
)
carotenoids.add_relation(RelationType.BT, phytochemicals)

lycopene = add_preferred_with_synonyms(
    builder, 
    "lycopene", 
    synonyms=["licopeno"]
)
lycopene.add_relation(RelationType.BT, carotenoids)

antioxidant_activity = add_preferred_with_synonyms(
    builder,
    "antioxidant activity",
    synonyms=["antioxidant capacity", "ORAC", "DPPH", "FRAP", "ABTS",
              "actividad antioxidante", "capacidad antioxidante"],
)
antioxidant_activity.add_relation(RelationType.RT, phytochemicals)

# Faceta E — Dominio (ciclo corto / horticultura) - BILINGÜE
horticulture = add_preferred_with_synonyms(
    builder, 
    "horticultural crops", 
    synonyms=["horticulture", "horticultur*", "cultivos hortícolas", "horticultura", 
              "cultivos hortofrutícolas"]
)

vegetables = add_preferred_with_synonyms(
    builder, 
    "vegetable crops", 
    synonyms=["vegetable crop*", "cultivos de hortalizas", "hortalizas", "verduras"]
)
vegetables.add_relation(RelationType.BT, horticulture)

fruit_crops = add_preferred_with_synonyms(
    builder, 
    "fruit crops", 
    synonyms=["fruit crop*", "cultivos frutales", "frutales", "frutas"]
)
fruit_crops.add_relation(RelationType.BT, horticulture)

annual_crops = add_preferred_with_synonyms(
    builder, 
    "annual crops", 
    synonyms=["short-season", "short season", "short-cycle", "short cycle",
              "cultivos anuales", "ciclo corto", "cultivos de ciclo corto"]
)
annual_crops.add_relation(RelationType.RT, horticulture)

# Faceta D alternativa (para más recall): resultados = (nutrición OR calidad)
nutrition_or_quality = add_preferred_with_synonyms(
    builder,
    "nutrition or quality outcomes",
    synonyms=["quality attributes", "quality parameters", "quality traits", "quality indicators",
              "atributos de calidad", "parámetros de calidad"],
)
nutritional_quality.add_relation(RelationType.BT, nutrition_or_quality)
fruit_quality.add_relation(RelationType.BT, nutrition_or_quality)

def print_queries(title: str, facets, include_related: bool = False):
    builder.facets = list(facets)
    print(f"\n===== {title} =====")
    print("Ecuación (Scopus):")
    print(builder.build_search_equation(database="scopus", include_related=include_related))
    print("\nEcuación (WoS):")
    print(builder.build_search_equation(database="wos", include_related=include_related))
    print("\nEcuación (IEEE):")
    print(builder.build_search_equation(database="ieee", include_related=include_related))
    print("\nEcuación (ScienceDirect, simplificada):")
    print(builder.build_search_equation(database="sciencedirect", include_related=include_related))

# Versión 1 (recomendada): core nutrición (nutrición es obligatoria)
core_nutrition_facets = (ai, plant_health, prediction, nutritional_quality, horticulture)
print_queries("Core nutrición (nutrición-first) - BILINGÜE", core_nutrition_facets, include_related=False)

# Versión 2: core nutrición + términos relacionados (mayor recall; más ruido)
print_queries("Core nutrición + RT (más recall) - BILINGÜE", core_nutrition_facets, include_related=True)

# Versión 2b (Scopus-friendly): (nutrición OR calidad) + RT (más recall)
nutrition_or_quality_facets = (ai, plant_health, prediction, nutrition_or_quality, horticulture)
print_queries("Nutrición OR calidad + RT (más recall) - BILINGÜE", nutrition_or_quality_facets, include_related=True)

# Versión 3: nutrición + rendimiento (más estricta)
nutrition_plus_yield_facets = (ai, plant_health, prediction, nutritional_quality, crop_yield, horticulture)
print_queries("Nutrición + rendimiento (más estricta) - BILINGÜE", nutrition_plus_yield_facets, include_related=False)

print("\nEstructura por facetas (core nutrición - BILINGÜE):")
for facet in core_nutrition_facets:
    print(f"\nFaceta: {facet.term}")
    builder.print_thesaurus_structure(facet)
# Out:
# ===== Core nutrición (nutrición-first) - BILINGÜE =====
# Ecuación (Scopus):
# ...

# %%
from thesaurus_builder import ThesaurusBuilder, RelationType

# %% [markdown]
# ## 1. Creación de un Tesauro Simple

# %%
# Crear el constructor
builder = ThesaurusBuilder()

# Crear términos principales con notas de alcance
ai = builder.add_term(
    "artificial intelligence",
    scope_note="Use for AI and artificial intelligence systems"
)

# Crear término no preferido
ai_alt = builder.add_term("AI", is_preferred=False)
ai_alt.add_relation(RelationType.USE, ai)

# Crear términos más específicos
ml = builder.add_term(
    "machine learning",
    scope_note="Systems that can learn from data"
)
ml.add_relation(RelationType.BT, ai)  # ML es más específico que AI

# Añadir como faceta y construir ecuación
builder.add_facet(ai)
print("Ecuación de búsqueda simple:")
print(builder.build_search_equation())
# Out:
# Ecuación de búsqueda simple:
# (("AI" OR "artificial intelligence" OR "machine learning"))

# %% [markdown]
# # Version final scopus
#
# TITLE-ABS-KEY(("AI" OR "CNN" OR "RNN" OR "artificial intelligence" OR "computer vision" OR "convolutional neural networks" OR "deep learning" OR "image processing" OR "machine learning" OR "random forest" OR "recurrent neural networks" OR "remote sensing" OR "support vector machine" OR "transformer model*" OR "transformers") AND ("bacterial diseases" OR "crop disease*" OR "disease detection" OR "disease incidence" OR "disease severity" OR "fungal diseases" OR "plant disease*" OR "plant diseases" OR "plant health" OR "plant pathogens" OR "viral diseases") AND ("classification" OR "early detection" OR "early warning" OR "estimation" OR "forecasting" OR "monitoring" OR "prediction" OR "regression") AND ("Ca" OR "Fe" OR "K" OR "TFC" OR "TPC" OR "Zn" OR "anthocyanin content" OR "anthocyanins" OR "antioxidant activity" OR "ascorbic acid" OR "bioactive compounds" OR "calcium" OR "carbohydrate content" OR "carbohydrate*" OR "carotenoid content" OR "carotenoids" OR "chemical composition" OR "color" OR "dietary fiber" OR "fat content" OR "fiber content" OR "fibre" OR "firmness" OR "flavonoid content" OR "flavonoids" OR "food composition" OR "fruit quality" OR "fruit weight" OR "harvest quality" OR "iron" OR "lipid content" OR "lipid*" OR "lycopene" OR "macronutrients" OR "microminerals" OR "micronutrients" OR "mineral composition" OR "mineral content" OR "minerals" OR "nutrient analysis" OR "nutrient content" OR "nutrient profile" OR "nutrition or quality outcomes" OR "nutritional analysis" OR "nutritional composition" OR "nutritional profile" OR "nutritional quality" OR "nutritional value" OR "phenolic compounds" OR "phenolic content" OR "phytochemicals" OR "phytonutrients" OR "polyphenols" OR "potassium" OR "protein content" OR "protein" OR "proximate analysis" OR "proximate composition" OR "quality assessment" OR "quality attributes" OR "quality indicators" OR "quality parameters" OR "quality traits" OR "sugar content" OR "total flavonoid content" OR "total phenolic content" OR "total soluble solids" OR "trace elements" OR "vitamin C" OR "vitamin content" OR "vitamins" OR "zinc") AND ("annual crops" OR "fruit crop*" OR "fruit crops" OR "horticultur*" OR "horticultural crops" OR "horticulture" OR "vegetable crop*" OR "vegetable crops"))

# %% [markdown]
# # Version final sciencedirect
#
# "artificial intelligence" AND "plant health" AND "prediction" AND ("nutrition" OR "quality outcomes") AND "horticultural crops"

# %% [markdown]
# # Version final IEEE
#
# ("AI" OR "CNN" OR "RNN" OR "artificial intelligence" OR "computer vision" OR "convolutional neural networks" OR "deep learning" OR "image processing" OR "machine learning" OR "random forest" OR "recurrent neural networks" OR "remote sensing" OR "support vector machine" OR "transformer model*" OR "transformers") AND ("bacterial diseases" OR "crop disease*" OR "disease detection" OR "disease incidence" OR "disease severity" OR "fungal diseases" OR "plant disease*" OR "plant diseases" OR "plant health" OR "plant pathogens" OR "viral diseases") AND ("classification" OR "early detection" OR "early warning" OR "estimation" OR "forecasting" OR "monitoring" OR "prediction" OR "regression") AND ("Ca" OR "Fe" OR "K" OR "TFC" OR "TPC" OR "Zn" OR "anthocyanin content" OR "anthocyanins" OR "antioxidant activity" OR "ascorbic acid" OR "bioactive compounds" OR "calcium" OR "carbohydrate content" OR "carbohydrate*" OR "carotenoid content" OR "carotenoids" OR "chemical composition" OR "color" OR "dietary fiber" OR "fat content" OR "fiber content" OR "fibre" OR "firmness" OR "flavonoid content" OR "flavonoids" OR "food composition" OR "fruit quality" OR "fruit weight" OR "harvest quality" OR "iron" OR "lipid content" OR "lipid*" OR "lycopene" OR "macronutrients" OR "microminerals" OR "micronutrients" OR "mineral composition" OR "mineral content" OR "minerals" OR "nutrient analysis" OR "nutrient content" OR "nutrient profile" OR "nutrition or quality outcomes" OR "nutritional analysis" OR "nutritional composition" OR "nutritional profile" OR "nutritional quality" OR "nutritional value" OR "phenolic compounds" OR "phenolic content" OR "phytochemicals" OR "phytonutrients" OR "polyphenols" OR "potassium" OR "protein content" OR "protein" OR "proximate analysis" OR "proximate composition" OR "quality assessment" OR "quality attributes" OR "quality indicators" OR "quality parameters" OR "quality traits" OR "sugar content" OR "total flavonoid content" OR "total phenolic content" OR "total soluble solids" OR "trace elements" OR "vitamin C" OR "vitamin content" OR "vitamins" OR "zinc") AND ("annual crops" OR "fruit crop*" OR "fruit crops" OR "horticultur*" OR "horticultural crops" OR "horticulture" OR "vegetable crop*" OR "vegetable crops")

# %% [markdown]
# # Version final WOS
#
# ("AI" OR "CNN" OR "RNN" OR "artificial intelligence" OR "computer vision" OR "convolutional neural networks" OR "deep learning" OR "image processing" OR "machine learning" OR "random forest" OR "recurrent neural networks" OR "remote sensing" OR "support vector machine" OR "transformer model*" OR "transformers") AND ("bacterial diseases" OR "crop disease*" OR "disease detection" OR "disease incidence" OR "disease severity" OR "fungal diseases" OR "plant disease*" OR "plant diseases" OR "plant health" OR "plant pathogens" OR "viral diseases") AND ("classification" OR "early detection" OR "early warning" OR "estimation" OR "forecasting" OR "monitoring" OR "prediction" OR "regression") AND ("Ca" OR "Fe" OR "K" OR "TFC" OR "TPC" OR "Zn" OR "anthocyanin content" OR "anthocyanins" OR "antioxidant activity" OR "ascorbic acid" OR "bioactive compounds" OR "calcium" OR "carbohydrate content" OR "carbohydrate*" OR "carotenoid content" OR "carotenoids" OR "chemical composition" OR "color" OR "dietary fiber" OR "fat content" OR "fiber content" OR "fibre" OR "firmness" OR "flavonoid content" OR "flavonoids" OR "food composition" OR "fruit quality" OR "fruit weight" OR "harvest quality" OR "iron" OR "lipid content" OR "lipid*" OR "lycopene" OR "macronutrients" OR "microminerals" OR "micronutrients" OR "mineral composition" OR "mineral content" OR "minerals" OR "nutrient analysis" OR "nutrient content" OR "nutrient profile" OR "nutrition or quality outcomes" OR "nutritional analysis" OR "nutritional composition" OR "nutritional profile" OR "nutritional quality" OR "nutritional value" OR "phenolic compounds" OR "phenolic content" OR "phytochemicals" OR "phytonutrients" OR "polyphenols" OR "potassium" OR "protein content" OR "protein" OR "proximate analysis" OR "proximate composition" OR "quality assessment" OR "quality attributes" OR "quality indicators" OR "quality parameters" OR "quality traits" OR "sugar content" OR "total flavonoid content" OR "total phenolic content" OR "total soluble solids" OR "trace elements" OR "vitamin C" OR "vitamin content" OR "vitamins" OR "zinc") AND ("annual crops" OR "fruit crop*" OR "fruit crops" OR "horticultur*" OR "horticultural crops" OR "horticulture" OR "vegetable crop*" OR "vegetable crops")
